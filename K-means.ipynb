# %%
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

plt.scatter(x, y)
plt.show()

# %%
import random

# %%
# !pip3 install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp39-cp39-macosx_12_0_arm64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 2.1 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: numpy>=1.17.3 in /Users/hardik/miniforge3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.22.3)
# Collecting joblib>=1.0.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 KB 2.6 MB/s eta 0:00:00a 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy>=1.3.2 in /Users/hardik/miniforge3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.8.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=f71f384d8c46b280c62f65d3a8f8eb8838449fa0693ea03ffad46cbe603ae0bf
#   Stored in directory: /Users/hardik/Library/Caches/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.1.2 sklearn-0.0 threadpoolctl-3.1.0

# %%
from sklearn.cluster import KMeans

data = list(zip(x, y))
inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
print(x)
random.shuffle(x)
x
# Out:
# [4, 10, 11, 6, 3, 10, 14, 12, 4, 5]
# [14, 10, 11, 4, 10, 12, 3, 4, 6, 5]

# %%
# !pip3 install nltk
# Out:
# Requirement already satisfied: nltk in /Users/hardik/miniforge3/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: tqdm in /Users/hardik/miniforge3/lib/python3.9/site-packages (from nltk) (4.64.0)
# Requirement already satisfied: click in /Users/hardik/miniforge3/lib/python3.9/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /Users/hardik/miniforge3/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/hardik/miniforge3/lib/python3.9/site-packages (from nltk) (2022.8.17)

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/hardik/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /Users/hardik/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
quotes = []
f = open("love-quotes.txt","r")
for line in f:
    
    quotes.append( {line : 'romance'} )
f.close()

f = open("tragedy-quotes.txt","r")
for line in f:
    quotes.append( {line : 'tragedy'} )
f.close()

f = open("comedy-quotes.txt","r")
for line in f:
    quotes.append( {line : 'comedy'} )
f.close()

# %%
random.shuffle(quotes)
print(quotes)
# Out:
# [{"Now, this is where I draw the line! It's bad enough everybody in town's going to be thinkin' I'm sleeping with a depressed, lice-ridden, hemorrhoidal foreigner who likes to be tied up and might be pregnant, although-since she's just about cornered the market on condoms-I don't know how that could have happened. But I will not-you listen to me, Emma!-I absolutely will not have anybody thinkin' a woman of mine needs a vaginal moisturizer, do you hear me?\n": 'comedy'}, {'Love is not a volunteer thing\n': 'romance'}, {'The chance to love and be loved exists no matter where you are\n': 'romance'}, {'Who is to decide which is the grimmer sight: withered hearts, or empty skulls?\n': 'tragedy'}, {'I fart in your general direction.\n': 'comedy'}, {"You think I'm deranged! How refreshing. Everyone here takes me so seriously, it's a wonderful change to be thought mentally deficient.\n": 'comedy'}, {'Tragedy, he precieved, belonged to the ancient time, to a time when there were still privacy, love, and friendship, and when the members of a family stood by one another without needing to know the reason.\n': 'tragedy'}, {'[Comedies], in the ancient world, were regarded as of a higher rank than tragedy, of a deeper truth, of a more difficult realization, of a sounder structure, and of a revelation more complete. The happy ending of the fairy tale, the myth, and the divine comedy of the soul, is to be read, not as a contradiction, but as a transcendence of the universal tragedy of man.... Tragedy is the shattering of the forms and of our attachments to the forms; comedy, the wild and careless, inexhaustible joy of life invincible.\n': 'comedy'}, {"One should never give up on hope. Unless that's the name of the girl who cheated on you in which case, yeah, give her up\n": 'comedy'}, {'It’s absolutely stupid that we live without an ozone layer. We have men, we’ve got rockets, we’ve got saran wrap – FIX IT!!!\n': 'comedy'}, {"It bothered me that whatever was waiting wasn't waiting for me\n": 'tragedy'}, {'And those who only know the non-platonic love have no need to talk of tragedy. In such love there can be no sort of tragedy.\n': 'tragedy'}, {'If she was broken, she would slash him with her jagged edges, reckless as a drunkard with a shattered bottle.\n': 'tragedy'}, {'Today you are You, that is truer than true. There is no one alive who is Youer than You.\n': 'comedy'}, {'Her lips full and inviting, she has an infectious laugh and glassy cackle in her eyes, and a 2000 volt sexual charisma that beckons me like a fluff girl on scuffed knees.\n': 'comedy'}, {'How do I love thee? Let me count the ways. I love thee to the depth and breadth and height My soul can reach\n': 'romance'}, {'If you live to be a hundred, I want to live to be a hundred minus one day so I never have to live without you\n': 'romance'}, {'Thankfully, persistence is a great substitute for talent.\n': 'comedy'}, {'The tragedy in a man’s life is what dies inside of him while he lives.\n': 'tragedy'}, {"A person’s tragedy does not make up their entire life. A story carves deep grooves into our brains each time we tell it. But we aren't one story. We can change our stories. We can write our own.\n": 'tragedy'}, {'I believe there are some things in life you can’t deny or rationalize, and [love] is one of them\n': 'romance'}, {'The whole world can become the enemy when you lose what you love.\n': 'tragedy'}, {'He means he’s GOING for a JOG\n': 'comedy'}, {'Only true love can fuel the hard work that awaits you\n': 'romance'}, {'For small creatures such as we, the vastness is bearable only through love\n': 'romance'}, {"I did not know then how much was ended. When I look back now from this high hill of my old age, I can still see the butchered women and children lying heaped and scattered all along the crooked gulch as plain as when I saw them with eyes still young. And I can see that something else died there in the bloody mud, and was buried in the blizzard. A people's dream die ...
